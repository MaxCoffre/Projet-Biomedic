# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
df=pd.read_csv("Biomedic_clean3.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'ID', 'ID Name', 'Souches', 'Diabetes', 'Hypertension',
#        'Hospital_before', 'Infection_Freq', 'AMX/AMP', 'AMC', 'CZ', 'FOX',
#        'CTX/CRO', 'IPM', 'GEN', 'AN', 'Acide nalidixique', 'ofx', 'CIP', 'C',
#        'Co-trimoxazole', 'Furanes', 'colistine', 'Collection_Date',
#        'Etat_Complet', 'Pays', 'Ville', 'age', 'gender', 'Age_Group',
#        'Unnamed: 0', 'Population', 'Temp. Min Moy. Annuelle (°C)',
#        'Temp. Moy. Annuelle (°C)', 'Temp. Max Moy. Annuelle (°C)',
#        'Humidité Moyenne (%)', 'Ensoleillement Moyen (heures/an)',
#        'Pluviométrie Moyenne (mm/an)', 'age_cat', 'Mobility', 'Multi_res'],
#       dtype='object')

# %%
dico_ttest={}
souches = df['Souches'].unique()
facteurs=['Diabetes','Hypertension','Hospital_before','Infection_Freq']

for s in souches:
    for fact in facteurs:
        df_temp = df.loc[df['Souches'] == s][[fact, 'AMX/AMP', 'AMC', 'CZ', 'FOX','CTX/CRO', 'IPM', 'GEN', 'AN', 'Acide nalidixique', 'ofx', 'CIP', 'C','Co-trimoxazole', 'Furanes', 'colistine']]
        test = st.ttest_ind(df_temp.loc[df_temp[fact]==1].iloc[:,1:], df_temp.loc[df_temp[fact]==0].iloc[:,1:], equal_var=False)
        dico_ttest[(s, fact)] = test.pvalue

df_ttest = pd.DataFrame(dico_ttest).T
df_ttest.columns = ['AMX/AMP', 'AMC', 'CZ', 'FOX','CTX/CRO', 'IPM', 'GEN', 'AN', 'Acide nalidixique', 'ofx', 'CIP', 'C','Co-trimoxazole', 'Furanes', 'colistine']

# %%
df_ttest
# Out:
#                                           AMX/AMP       AMC        CZ  \
# ESCHERICHIA COLI        Diabetes         0.884558  0.238450  0.606511
#                         Hypertension     0.334414  0.119258  0.224656
#                         Hospital_before  0.221554  0.445790  0.597207
#                         Infection_Freq   0.604337  0.135672  0.710903
# MORGANELLA MORGANII     Diabetes         0.210917  0.196733  0.482223
#                         Hypertension     0.959943  0.554785  0.873170
#                         Hospital_before  0.594898  0.626009  0.194083
#                         Infection_Freq   0.026943  0.018896  0.368989
# PROTEUS MIRABILIS       Diabetes         0.035581  0.767766  0.698761
#                         Hypertension     0.677297  0.989817  0.000275
#                         Hospital_before  0.792437  0.913779  0.011303
#                         Infection_Freq   0.860457  0.539276  0.490114
# ...

# %%
df_ttest.to_csv("ttest_results.csv")

# %%
for col in df_ttest.columns:
    df_ttest[col] = df_ttest[col].apply(lambda x: '<0.05' if x < 0.05 else '>=0.05')

# %%
df_ttest.T.loc[df_ttest.T[('ESCHERICHIA COLI', 'Diabetes')] == '<0.05'].index
# Out:
# Index(['AN', 'colistine'], dtype='object')

# %%
for (s,fact) in df_ttest.index:
    sigs = df_ttest.loc[(s,fact)][df_ttest.loc[(s,fact)] == '<0.05'].index.tolist()
    if len(sigs) > 0:
        print(f"Pour {s}, {fact} entraîne une modification significative du taux de résistance à: {sigs}")
# Out:
# Pour ESCHERICHIA COLI, Diabetes entraîne une modification significative du taux de résistance à: ['AN', 'colistine']
# Pour ESCHERICHIA COLI, Hypertension entraîne une modification significative du taux de résistance à: ['Acide nalidixique', 'C']
# Pour ESCHERICHIA COLI, Hospital_before entraîne une modification significative du taux de résistance à: ['FOX']
# Pour MORGANELLA MORGANII, Hospital_before entraîne une modification significative du taux de résistance à: ['C']
# Pour MORGANELLA MORGANII, Infection_Freq entraîne une modification significative du taux de résistance à: ['AMX/AMP', 'AMC']
# Pour PROTEUS MIRABILIS, Diabetes entraîne une modification significative du taux de résistance à: ['AMX/AMP', 'Acide nalidixique']
# Pour PROTEUS MIRABILIS, Hypertension entraîne une modification significative du taux de résistance à: ['CZ']
# Pour PROTEUS MIRABILIS, Hospital_before entraîne une modification significative du taux de résistance à: ['CZ']
# ...
